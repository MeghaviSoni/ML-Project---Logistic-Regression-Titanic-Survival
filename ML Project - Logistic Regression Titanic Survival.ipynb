# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Meghavi Soni\Downloads\ML Project - Logistic Regression Titanic Survival U16955478860.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
x = data.drop(["Survived","Name","Ticket"],axis=1)

# %%
y = data["Survived"]

# %%
x
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare        Cabin  \
# 1              2       1  female  38.0      1      0  71.2833          C85
# 3              4       1  female  35.0      1      0  53.1000         C123
# 6              7       1    male  54.0      0      0  51.8625          E46
# 10            11       3  female   4.0      1      1  16.7000           G6
# 11            12       1  female  58.0      0      0  26.5500         C103
# ..           ...     ...     ...   ...    ...    ...      ...          ...
# 871          872       1  female  47.0      1      1  52.5542          D35
# 872          873       1    male  33.0      0      0   5.0000  B51 B53 B55
# 879          880       1  female  56.0      0      1  83.1583          C50
# 887          888       1  female  19.0      0      0  30.0000          B42
# 889          890       1    male  26.0      0      0  30.0000         C148
#
#     Embarked
# 1          C
# 3          S
# 6          S
# 10         S
# 11         S
# ..       ...
# 871        S
# 872        S
# 879        C
# 887        S
# 889        C
#
# [183 rows x 9 columns]

# %%
y
# Out:
# 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: Survived, Length: 183, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc =LabelEncoder()

# %%
x['Sex'] = enc.fit_transform(x['Sex'])

# %%
x['Cabin'] = enc.fit_transform(x['Cabin'])
x['Embarked'] = enc.fit_transform(x['Embarked'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.8,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# C:\Users\Meghavi Soni\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf.score(x_test,y_test)
# Out:
# 0.7687074829931972

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,f1_score

# %%
y_pred = clf.predict(x_test)

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[30, 16],
#        [18, 83]], dtype=int64)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7687074829931972

# %%
precision_score(y_pred,y_test)
# Out:
# 0.8383838383838383

# %%
recall_score(y_pred,y_test)
# Out:
# 0.8217821782178217

# %%
f1_score(y_pred,y_test)
# Out:
# 0.83

# %%
y_prob = clf.predict_proba(x_test)

# %%
y_prob
# Out:
# array([[0.17737206, 0.82262794],
#        [0.66608397, 0.33391603],
#        [0.55622232, 0.44377768],
#        [0.65927139, 0.34072861],
#        [0.10441569, 0.89558431],
#        [0.43502223, 0.56497777],
#        [0.1250334 , 0.8749666 ],
#        [0.50803118, 0.49196882],
#        [0.17499594, 0.82500406],
#        [0.26203016, 0.73796984],
#        [0.61078474, 0.38921526],
#        [0.43172405, 0.56827595],
#        [0.0895106 , 0.9104894 ],
#        [0.50640373, 0.49359627],
#        [0.0373147 , 0.9626853 ],
#        [0.13661443, 0.86338557],
#        [0.13649074, 0.86350926],
#        [0.17047632, 0.82952368],
#        [0.17869068, 0.82130932],
#        [0.0602244 , 0.9397756 ],
#        [0.02762388, 0.97237612],
#        [0.15860249, 0.84139751],
#        [0.2412469 , 0.7587531 ],
#        [0.50339527, 0.49660473],
#        [0.35396796, 0.64603204],
#        [0.65822242, 0.34177758],
#        [0.55183936, 0.44816064],
#        [0.3384838 , 0.6615162 ],
#        [0.49224851, 0.50775149],
#        [0.50784544, 0.49215456],
#        [0.15775741, 0.84224259],
#        [0.21978   , 0.78022   ],
#        [0.06469604, 0.93530396],
#        [0.22087916, 0.77912084],
#        [0.13356554, 0.86643446],
#        [0.16235948, 0.83764052],
#        [0.22039657, 0.77960343],
#        [0.18663928, 0.81336072],
#        [0.09482675, 0.90517325],
#        [0.82263943, 0.17736057],
#        [0.41567555, 0.58432445],
#        [0.57528773, 0.42471227],
#        [0.56326702, 0.43673298],
#        [0.07280542, 0.92719458],
#        [0.74656106, 0.25343894],
#        [0.08094846, 0.91905154],
#        [0.49513881, 0.50486119],
#        [0.57124636, 0.42875364],
#        [0.74206554, 0.25793446],
#        [0.1525452 , 0.8474548 ],
#        [0.55450882, 0.44549118],
#        [0.08329396, 0.91670604],
#        [0.51177003, 0.48822997],
#        [0.08113219, 0.91886781],
#        [0.31961438, 0.68038562],
#        [0.01335198, 0.98664802],
#        [0.29882515, 0.70117485],
#        [0.5622959 , 0.4377041 ],
#        [0.08738107, 0.91261893],
#        [0.67165332, 0.32834668],
#        [0.73390503, 0.26609497],
#        [0.15450259, 0.84549741],
#        [0.13470821, 0.86529179],
#        [0.5937169 , 0.4062831 ],
#        [0.25569472, 0.74430528],
#        [0.74921393, 0.25078607],
#        [0.15047131, 0.84952869],
#        [0.40205452, 0.59794548],
#        [0.27953221, 0.72046779],
#        [0.37667404, 0.62332596],
#        [0.19099838, 0.80900162],
#        [0.32395439, 0.67604561],
#        [0.72872023, 0.27127977],
#        [0.06795281, 0.93204719],
#        [0.10566352, 0.89433648],
#        [0.26152669, 0.73847331],
#        [0.73705082, 0.26294918],
#        [0.48788073, 0.51211927],
#        [0.19858432, 0.80141568],
#        [0.10775772, 0.89224228],
#        [0.18699472, 0.81300528],
#        [0.32918412, 0.67081588],
#        [0.46615159, 0.53384841],
#        [0.11747844, 0.88252156],
#        [0.33556377, 0.66443623],
#        [0.4389047 , 0.5610953 ],
#        [0.56679493, 0.43320507],
#        [0.23900745, 0.76099255],
#        [0.60183683, 0.39816317],
#        [0.59834068, 0.40165932],
#        [0.12136724, 0.87863276],
#        [0.24681163, 0.75318837],
#        [0.32771166, 0.67228834],
#        [0.59224547, 0.40775453],
#        [0.57620741, 0.42379259],
#        [0.25987873, 0.74012127],
#        [0.04566096, 0.95433904],
#        [0.03056677, 0.96943323],
#        [0.92991491, 0.07008509],
#        [0.36746857, 0.63253143],
#        [0.06175819, 0.93824181],
#        [0.34497559, 0.65502441],
#        [0.21561443, 0.78438557],
#        [0.86015004, 0.13984996],
#        [0.36300273, 0.63699727],
#        [0.58752455, 0.41247545],
#        [0.66306622, 0.33693378],
#        [0.07581085, 0.92418915],
#        [0.30244682, 0.69755318],
#        [0.05670503, 0.94329497],
#        [0.07367608, 0.92632392],
#        [0.14795911, 0.85204089],
#        [0.48770698, 0.51229302],
#        [0.35918035, 0.64081965],
#        [0.17547717, 0.82452283],
#        [0.44313577, 0.55686423],
#        [0.76954282, 0.23045718],
#        [0.61435182, 0.38564818],
#        [0.52293512, 0.47706488],
#        [0.58930817, 0.41069183],
#        [0.46077524, 0.53922476],
#        [0.15837488, 0.84162512],
#        [0.73427237, 0.26572763],
#        [0.17173007, 0.82826993],
#        [0.51759207, 0.48240793],
#        [0.19596624, 0.80403376],
#        [0.56524021, 0.43475979],
#        [0.29402132, 0.70597868],
#        [0.63927306, 0.36072694],
#        [0.20052137, 0.79947863],
#        [0.5952274 , 0.4047726 ],
#        [0.10247157, 0.89752843],
#        [0.08601382, 0.91398618],
#        [0.93198847, 0.06801153],
#        [0.11489647, 0.88510353],
#        [0.18598323, 0.81401677],
#        [0.49847058, 0.50152942],
#        [0.33384818, 0.66615182],
#        [0.43602587, 0.56397413],
#        [0.40861425, 0.59138575],
#        [0.7212887 , 0.2787113 ],
#        [0.03730127, 0.96269873],
#        [0.1204443 , 0.8795557 ],
#        [0.11078585, 0.88921415],
#        [0.10153028, 0.89846972],
#        [0.76652283, 0.23347717],
#        [0.09017396, 0.90982604]])

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y_pred_proba = clf.predict_proba(x_test)[::,1]
fpr, tpr, threshold = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc=" +str(auc))
plt.legend(loc=4)
plt.xlabel("False Positive Rate")
plt.ylabel(" Positive Rate")

plt.show()
